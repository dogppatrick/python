# %%
import pandas as pd
import glob
import time
c = ["path", "target"]
df = pd.DataFrame(columns=c)
cat = glob.glob("train/cat.*")
dog = glob.glob("train/dog.*")
a1_t1 = time.time()
# for fn in cat:
#     s = pd.Series([fn, 0], index=c)
#     df = df.append(s, ignore_index=True)
# for fn in dog:
#     s = pd.Series([fn, 1], index=c)
#     df = df.append(s, ignore_index=True)
print("load time =", time.time()-a1_t1)
# Out:
# load time = 0.0

# %%
import numpy as np
# try to load data name by np.array
a1_t1 = time.time()
cat_r = np.array(cat)
dog_r = np.array(dog)
y_cat = np.repeat(0, len(cat_r))
y_dog = np.repeat(1, len(dog_r))
data_cat = np.column_stack((cat_r[:], y_cat[:]))
data_dog = np.column_stack((dog_r[:], y_dog[:]))
con_data = np.concatenate((data_cat, data_dog), axis=0)
print(con_data)
df2 = pd.DataFrame(con_data, columns=c)
print("load time =", time.time()-a1_t1)
df2
# Out:
# [['train\\cat.0.jpg' '0']
#  ['train\\cat.1.jpg' '0']
#  ['train\\cat.10.jpg' '0']
#  ...
#  ['train\\dog.9997.jpg' '1']
#  ['train\\dog.9998.jpg' '1']
#  ['train\\dog.9999.jpg' '1']]
# load time = 0.026926755905151367
#                       path target
# 0          train\cat.0.jpg      0
# 1          train\cat.1.jpg      0
# 2         train\cat.10.jpg      0
# 3        train\cat.100.jpg      0
# 4       train\cat.1000.jpg      0
# 5      train\cat.10000.jpg      0
# 6      train\cat.10001.jpg      0
# 7      train\cat.10002.jpg      0
# 8      train\cat.10003.jpg      0
# 9      train\cat.10004.jpg      0
# 10     train\cat.10005.jpg      0
# 11     train\cat.10006.jpg      0
# 12     train\cat.10007.jpg      0
# 13     train\cat.10008.jpg      0
# 14     train\cat.10009.jpg      0
# 15      train\cat.1001.jpg      0
# 16     train\cat.10010.jpg      0
# 17     train\cat.10011.jpg      0
# 18     train\cat.10012.jpg      0
# 19     train\cat.10013.jpg      0
# ...

# %%
# import random
# display demo pic
# from keras.preprocessing.image import load_img
# n_raw =df.shape[0]
# pick = random.randint(0, n_raw)
# disp_data = df.iloc[pick]["path"]
# print(df.iloc[pick]["target"])
# load_img(disp_data)

# %%
from keras.applications.vgg16 import VGG16
vgg = VGG16(include_top=False, input_shape=(224, 224, 3))
vgg.summary()
# Out:
# ...
# 58892288/58889256 [==============================] - 263s 4us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# ...

# %%
#def test():
#    return print
#test()("hello")
from keras.models import Model
from keras.layers import Dense, Flatten, BatchNormalization
for l in vgg.layers:
    l.trainable =False
# 沒加BatchNormalization 死去
x = BatchNormalization()(vgg.output)
x = Flatten()(x)
x = Dense(1024, activation="relu")(x)
x = Dense(128, activation="relu")(x)
# 第一個選擇: 1 activation="sigmoid"
# 第二個選擇: 2 activation="softmax"
x = Dense(2, activation="softmax")(x)
cnn = Model(inputs=vgg.input, outputs=x)
cnn.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
cnn.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
from sklearn.model_selection import train_test_split
x = np.array(df["path"])
y = np.array(df["target"])
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size= 0.1)

# %%
from keras.utils.np_utils import to_categorical
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %%
from keras.applications.vgg16 import preprocess_input
# numpy raindint 不含上界  =< 0 <
train_t = 10
batch = 10
for j in range(train_t):
    idx = np.random.randint(0, x_train.shape[0], size=batch)
    imglist = []
    for i in range(batch):
        fn = x_train[idx[i]]
        img = load_img(fn, target_size=(224,224))
        imglist.append(preprocess_input(np.array(img)))
    xs = np.array(imglist)
    ys = y_train_cat[idx]
    result = cnn.train_on_batch(xs, ys)
    print(result)
# Out:
# [1.6118095, 0.9]
# [1.6373303, 0.9]
# [0.0019773585, 1.0]
# [0.3165794, 0.9]
# [1.6118095, 0.9]
# [3.2236824, 0.8]
# [0.020716203, 1.0]
# [1.6399496, 0.9]
# [3.309545, 0.7]
# [4.141397, 0.6]

# %%
from keras.applications.vgg16 import preprocess_input
# numpy raindint 不含上界  =< 0 <_t = 10
test = 100
idx = np.random.randint(0, x_test.shape[0], size=test)
imglist = []
for i in range(test):
    fn = x_test[idx[i]]
    img = load_img(fn, target_size=(224,224))
    imglist.append(preprocess_input(np.array(img)))
    xs = np.array(imglist)
ys = y_test_cat[idx]
cnn.evaluate(xs, ys)
# Out:
# 100/100 [==============================] - 21s 209ms/step
# [2.6338127136230467, 0.8]
