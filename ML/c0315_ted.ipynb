# %%
import pandas as pd
from datetime import datetime
df = pd.read_csv("ted_main.csv", encoding="utf-8")
# df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
# df[ ["comments", "description"] ]

# %%
# df.iloc[0]

# %%
# df.iloc[0,1]

# %%
# apply: Series.apply(流程)
# ()->執行意思, apply還沒要執行, 只給流程名字
def timeflow(timestamp):
    return str(datetime.utcfromtimestamp(timestamp))
df["film_date_utc"] = df["film_date"].apply(timeflow)
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
name = "AI"
def tagflow(self, **kwargs):
    tags = eval(self)
    return kwargs["t"] in tags
a = df[ df["tags"].apply(tagflow,t = name)]
c = [1,2,3,4]
a.iloc[:,c]
# Out:
#                                             description  duration  \
# 106   Treo creator Jeff Hawkins urges us to take a n...      1211
# 151   Hod Lipson demonstrates a few of his cool litt...       378
# 302   In this prophetic talk from 2003, roboticist R...      1127
# 658   Meet seven all-terrain robots -- like the huma...       955
# 745   Peter Molyneux demos Milo, a hotly anticipated...       655
# 853   In this first-of-its-kind demo, Heather Knight...       364
# 865   Cynthia Breazeal wonders: Why can we use robot...       844
# 1051  Neuroscientist Daniel Wolpert starts from a su...      1199
# 1055  In his lab, Martin Hanczyc makes "protocells,"...       877
# 1162  In his lab at Penn, Vijay Kumar and his team b...      1006
# 1194  As we expect more from technology, do we expec...      1188
# 1244  The more that robots ingrain themselves into o...      1029
# 1321  Brute computing force alone can't solve the wo...       732
# ...

# %%
a.T
# Out:
#                                                                  106   \
# comments                                                          230
# description         Treo creator Jeff Hawkins urges us to take a n...
# duration                                                         1211
# event                                                         TED2003
# film_date                                                  1044144000
# languages                                                          29
# main_speaker                                             Jeff Hawkins
# name                Jeff Hawkins: How brain science will change co...
# num_speaker                                                         1
# published_date                                             1179760080
# ratings             [{'id': 3, 'name': 'Courageous', 'count': 73},...
# related_talks       [{'id': 184, 'hero': 'https://pe.tedcdn.com/im...
# ...
