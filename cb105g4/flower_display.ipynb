# %%
import pandas as pd
import numpy as np
data = pd.read_csv("flower_bus.csv", encoding="utf-8")
arr_d = np.array(data)
# data["設立日期"]
c = data.columns.tolist()
# data[c[1]]
for i in range(len(c)):
    cl = i
    print(c[cl],i, end="\t")
    print(arr_d[:,cl])
# Out:
# 營業地址 0	['南投縣中寮鄉永平村１２鄰永平路２６５―１號' '南投縣中寮鄉福盛村００１鄰永樂路７３－３號一樓' '南投縣仁愛鄉互助村中華路９５號' ...
#  '高雄市鳳山區東門里中山東路１２０號１樓' '高雄市鳳山區東門里中山東路３２巷２３號１樓' '高雄市鳳山區東門里光遠東路２４號１樓']
# 統一編號 1	[25226862 38962907 25275933 ... 47687516 80952917 21606546]
# 總機構統一編號 2	[nan nan nan ... nan nan nan]
# 營業人名稱 3	['宜欣花店' '永樂花卉農場' '福亨農產加工廠' ... '京城異品複合百貨館' '馨穎商行' '耍花樣花藝創作坊']
# 資本額 4	[500000 50000 200000 ... 99999 6000 200000]
# 設立日期 5	[980609 1040109 980401 ... 1050818 920813 940308]
# 組織別名稱 6	['獨資' '獨資' '獨資' ... '獨資' '獨資' '獨資']
# 使用統一發票 7	['N' 'N' 'N' ... 'N' 'N' 'N']
# 行業代號 8	[963099 11799 83014 ... 485111 561113 485111]
# 名稱 9	['其他殯葬服務' '其他花卉栽培' '醃漬蔬菜、醃漬果實製造' ... '切花、盆栽零售' '麵店、小吃店' '切花、盆栽零售']
# 行業代號1 10	[nan nan 472113.0 ... 472915.0 11799.0 nan]
# 名稱1 11	[nan nan '醃漬蔬果零售' ... '茶葉零售' '其他花卉栽培' nan]
# 行業代號2 12	[nan nan 472999.0 ... 472918.0 472999.0 nan]
# 名稱2 13	[nan nan '未分類其他食品、飲料及菸草製品零售' ... '咖啡零售' '未分類其他食品、飲料及菸草製品零售' nan]
# 行業代號3 14	[nan nan 485111.0 ... nan nan nan]
# 名稱3 15	[nan nan '切花、盆栽零售' ... nan nan nan]

# %%
data
# Out:
#                                        營業地址      統一編號  總機構統一編號  \
# 0                     南投縣中寮鄉永平村１２鄰永平路２６５―１號  25226862      NaN
# 1                   南投縣中寮鄉福盛村００１鄰永樂路７３－３號一樓  38962907      NaN
# 2                           南投縣仁愛鄉互助村中華路９５號  25275933      NaN
# 3                       南投縣仁愛鄉南豐村中正路８７―６號１樓  24882138      NaN
# 4                         南投縣仁愛鄉南豐村中正路８７之６號   6127639      NaN
# 5                           南投縣仁愛鄉南豐村楓林路４３號  26919407      NaN
# 6                        南投縣仁愛鄉大同村仁和路１－１附１號  26869814      NaN
# 7                          南投縣仁愛鄉大同村仁和路２１５號  61819778      NaN
# 8                           南投縣仁愛鄉大同村榮光巷４０號  19260069      NaN
# 9                         南投縣仁愛鄉大同村榮光巷４６號１樓  21425405      NaN
# 10                         南投縣仁愛鄉大同村榮光巷８－４號  25228398      NaN
# 11                       南投縣仁愛鄉大同村１９鄰博望巷３２號  14616029      NaN
# 12                       南投縣仁愛鄉大同村４鄰仁和路１８２號   6115508      NaN
# 13                          南投縣仁愛鄉春陽村源泉巷６８號  14610799      NaN
# ...

# %%
# Out:
# array([['南投縣中寮鄉永平村１２鄰永平路２６５―１號', 25226862, nan, '宜欣花店', 500000, 980609,
#         '獨資', 'N', 963099, '其他殯葬服務', nan, nan, nan, nan, nan, nan],
#        ['南投縣中寮鄉福盛村００１鄰永樂路７３－３號一樓', 38962907, nan, '永樂花卉農場', 50000,
#         1040109, '獨資', 'N', 11799, '其他花卉栽培', nan, nan, nan, nan, nan,
#         nan],
#        ['南投縣仁愛鄉互助村中華路９５號', 25275933, nan, '福亨農產加工廠', 200000, 980401,
#         '獨資', 'N', 83014, '醃漬蔬菜、醃漬果實製造', 472113.0, '醃漬蔬果零售', 472999.0,
#         '未分類其他食品、飲料及菸草製品零售', 485111.0, '切花、盆栽零售'],
#        ['南投縣仁愛鄉南豐村中正路８７―６號１樓', 24882138, nan, '才谷園有限公司', 100000, 1040327,
#         '有限公司', 'Y', 453212, '種苗批發', 452000.0, '綜合商品批發', 462011.0,
#         '肥料批發', 485113.0, '花卉材料、園藝器具零售'],
#        ['南投縣仁愛鄉南豐村中正路８７之６號', 6127639, nan, '豐林園藝', 90000, 800124, '獨資',
#         'N', 11799, '其他花卉栽培', 11999.0, '其他農作物栽培', nan, nan, nan, nan]],
#       dtype=object)

# %%
cod=[8,10,12,14]
cod_d=list(range(9,15+1,2))
cod_ar = arr_d[:,cod]
cod_des = arr_d[:,cod_d]
cod_ar[:, 0:4]
# Out:
# array([[963099, nan, nan, nan],
#        [11799, nan, nan, nan],
#        [83014, 472113.0, 472999.0, 485111.0],
#        ...,
#        [485111, 472915.0, 472918.0, nan],
#        [561113, 11799.0, 472999.0, nan],
#        [485111, nan, nan, nan]], dtype=object)

# %%
arr_test = arr_d[0:5,cod]

arr_test
# Out:
# array([[963099, nan, nan, nan],
#        [11799, nan, nan, nan],
#        [83014, 472113.0, 472999.0, 485111.0],
#        [453212, 452000.0, 462011.0, 485113.0],
#        [11799, 11999.0, nan, nan]], dtype=object)
