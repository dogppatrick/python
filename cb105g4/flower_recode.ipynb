# %%
import pandas as pd
import numpy as np
import glob
import os
import time
path = os.path.abspath("")
print(path)
# Out:
# E:\python\cb105g4

# %%
# fn_list = glob.glob("data_source/*.*")
# print(fn_list)
fn_to_save = ["fc_die.csv", "fc_live.csv"]
for q in range(len(fn_to_save)):
    fn = fn_to_save[q]
    data = pd.read_csv(fn, encoding="utf-8")
    # data
    print(fn)
    # 新增 arr_d type np.array 用於計算
    arr_d = np.array(data)
    # c = 個別欄位名稱
    c = data.columns.tolist()
    for i in range(len(c)):
        print(c[i],i, end="\t")
        print(arr_d[0:10,i])
    data_raws = data.shape[0]
    # 行業代號
    b_c=np.array(list(range(8,14+1,2)))
    # 名稱
    b_n=np.array(list(range(9,15+1,2)))
    bs_code_new = []
    bn_code_new = []
    t1 = time.time()
    for i in range(data_raws):
        # l = 行業代號 去除nan 轉為int
        l = arr_d[i,b_c]
        l = l[~pd.isna(l)]
#         l = l.astype(int)
        bs_code_new.append(l)
        # l = 名稱 去除nan
        l = arr_d[i,b_n]
        l = l[~pd.isna(l)]
        bn_code_new.append(l)
    print(time.time()-t1)
    # print(bs_code_new,bn_code_new)
    data["行業代碼_new"]=bs_code_new
    data["名稱_new"]=bn_code_new
    data = data.drop(['名稱', '名稱1', '名稱2', '名稱3', '行業代號', 
                      '行業代號1', '行業代號2', '行業代號3', '總機構統一編號'], axis=1)
    fn = "recode_" + fn
    data.to_csv(fn, index=False, encoding="utf-8" )
    print("data saved", fn)
# Out:
# fc_die.csv
# 營業地址 0	['南投縣中寮鄉和興村００８鄰永樂路１４３號' '南投縣仁愛鄉南豐村１２鄰中正路１１８－３號' '南投縣南投市光輝里省府路７８號'
#  '南投縣南投市南投里２鄰民權街８７號' '南投縣南投市營北里仁義南路３４巷７號' '南投縣國姓鄉北港村北原路６８－２號'
#  '南投縣埔里鎮北安里三民路２６巷１０號１樓' '南投縣埔里鎮北安里１７鄰和平東路５３６號１樓' '南投縣埔里鎮北梅里１８鄰仁愛路５１１號'
#  '南投縣埔里鎮同聲里光華街９５巷３號１樓']
# 統一編號 1	[94920851 45651105 80590886 14606346 39919339 19258866 78121043 10920667
#  80088169 62164967]
# 總機構統一編號 2	[nan nan nan nan nan nan nan nan nan nan]
# 營業人名稱 3	['保証責任南投縣和興合作農場' '祥林園藝' '松濤園企業有限公司' '百合園藝' '中興蘭園' '松柏林園藝綠化土木工程行' '文通林業行'
#  '尚宏山業行' '順瓏農產有限公司' '統裕行']
# 資本額 4	[200000 90000 1200000 50000 200000 3000 600000 6000000 5000000 4700000]
# 設立日期 5	[920526 970411 921119 910916 1021210 891106 860620 991223 920128 600401]
# 停業日期 6	[1070712 1080101 1070601 1060930 1060911 1070821 1080228 1080130 1080201
#  1070630]
# 使用統一發票 7	['N' 'N' 'N' 'N' 'N' 'N' 'Y' 'N' 'Y' 'N']
# 行業代號 8	[453212 453212 453212 485111 485111 432000 20011 485112 453212 453212]
# 名稱 9	['種苗批發' '種苗批發' '種苗批發' '切花、盆栽零售' '切花、盆栽零售' '庭園景觀工程' '造林' '園藝苗木零售' '種苗批發'
#  '種苗批發']
# 行業代號1 10	[485112.0 711112.0 453211.0 nan 485112.0 432000.0 20013.0 20011.0 453113.0
#  813000.0]
# 名稱1 11	['園藝苗木零售' '景觀建築服務' '切花、盆栽批發' nan '園藝苗木零售' '庭園景觀工程' '伐木' '造林' '種子批發' '綠化服務']
# 行業代號2 12	[472935.0 485113.0 711112.0 nan 740999.0 429099.0 485112.0 nan 485111.0
#  20011.0]
# 名稱2 13	['青草零售' '花卉材料、園藝器具零售' '景觀建築服務' nan '未分類其他專門設計服務' '未分類其他土木工程' '園藝苗木零售' nan
#  '切花、盆栽零售' '造林']
# 行業代號3 14	[932999.0 485299.0 432000.0 nan nan nan 11799.0 nan 485112.0 11799.0]
# 名稱3 15	['未分類其他娛樂及休閒服務' '未分類其他全新商品零售' '庭園景觀工程' nan nan nan '其他花卉栽培' nan '園藝苗木零售'
#  '其他花卉栽培']
# 0.03792572021484375
# data saved recode_fc_die.csv
# fc_live.csv
# 營業地址 0	['南投縣中寮鄉永平村永安街１５０號' '南投縣中寮鄉永平村１２鄰永平路２６５―１號' '南投縣中寮鄉清水村瀧林巷９５－６號一樓'
#  '南投縣中寮鄉福盛村００１鄰永樂路７３－３號一樓' '南投縣仁愛鄉互助村中華路９５號' '南投縣仁愛鄉南豐村中正路８７―６號１樓'
#  '南投縣仁愛鄉南豐村中正路８７之６號' '南投縣仁愛鄉南豐村楓林路４３號' '南投縣仁愛鄉大同村仁和路１－１附１號'
#  '南投縣仁愛鄉大同村仁和路２１５號']
# 統一編號 1	[45618768 25226862 72425667 38962907 25275933 24882138 6127639 26919407
#  26869814 61819778]
# 總機構統一編號 2	[nan nan nan nan nan nan nan nan nan nan]
# 營業人名稱 3	['諾華商行' '宜欣花店' '香格里拉園藝社' '永樂花卉農場' '福亨農產加工廠' '才谷園有限公司' '豐林園藝' '花圤林木園藝種苗場'
#  '霧社小田尾' '國立臺灣大學生物資源暨農學院附設山地實驗農場']
# 資本額 4	[220000 500000 200000 50000 200000 100000 90000 5000000 50000 3000]
# 設立日期 5	[970311 980609 1060616 1040109 980401 1040327 800124 1001012 1000620
#  910620]
# 組織別名稱 6	['獨資' '獨資' '獨資' '獨資' '獨資' '有限公司' '獨資' '獨資' '獨資' '其他']
# 使用統一發票 7	['Y' 'N' 'N' 'N' 'N' 'Y' 'N' 'N' 'N' 'Y']
# 行業代號 8	[462016 963099 11999 11799 83014 453212 11799 11999 11799 11400]
# 名稱 9	['農藥批發' '其他殯葬服務' '其他農作物栽培' '其他花卉栽培' '醃漬蔬菜、醃漬果實製造' '種苗批發' '其他花卉栽培'
#  '其他農作物栽培' '其他花卉栽培' '蔬菜栽培']
# 行業代號1 10	[485113.0 nan nan nan 472113.0 452000.0 11999.0 nan 472999.0 11500.0]
# 名稱1 11	['花卉材料、園藝器具零售' nan nan nan '醃漬蔬果零售' '綜合商品批發' '其他農作物栽培' nan
#  '未分類其他食品、飲料及菸草製品零售' '果樹栽培']
# 行業代號2 12	[nan nan nan nan 472999.0 462011.0 nan nan 472915.0 11999.0]
# 名稱2 13	[nan nan nan nan '未分類其他食品、飲料及菸草製品零售' '肥料批發' nan nan '茶葉零售' '其他農作物栽培']
# 行業代號3 14	[nan nan nan nan 485111.0 485113.0 nan nan nan 11799.0]
# 名稱3 15	[nan nan nan nan '切花、盆栽零售' '花卉材料、園藝器具零售' nan nan nan '其他花卉栽培']
# 0.5186131000518799
# data saved recode_fc_live.csv

# %%
fn_to_save = ["fc_may_die.csv"]
for q in range(len(fn_to_save)):
    fn = fn_to_save[q]
    data = pd.read_csv(fn, encoding="utf-8")
    # data
    # 新增 arr_d type np.array 用於計算
    arr_d = np.array(data)
    # c = 個別欄位名稱
    c = data.columns.tolist()
    for i in range(len(c)):
        print(c[i],i, end="\t")
        print(arr_d[0:10,i])
    data_raws = data.shape[0]
    # 行業代號
    b_c=np.array(list(range(7,13+1,2)))
    # 名稱
    b_n=np.array(list(range(8,14+1,2)))
    bs_code_new = []
    bn_code_new = []
    t1 = time.time()
    for i in range(data_raws):
        # l = 行業代號 去除nan 轉為int
        l = arr_d[i,b_c]
        l = l[~pd.isna(l)]
#         l = l.astype(int)
        bs_code_new.append(l)
        # l = 名稱 去除nan
        l = arr_d[i,b_n]
        l = l[~pd.isna(l)]
        bn_code_new.append(l)
    print(time.time()-t1)
    # print(bs_code_new,bn_code_new)
    data["行業代碼_new"]=bs_code_new
    data["名稱_new"]=bn_code_new
    data = data.drop(['名稱', '名稱1', '名稱2', '名稱3', '行業代號', 
                      '行業代號1', '行業代號2', '行業代號3', '總機構統一編號'], axis=1)
    fn = "recode_" + fn
    data.to_csv(fn, index=False, encoding="utf-8" )
    print("data saved", fn)
# Out:
# 營業地址 0	['南投縣中寮鄉永平村９鄰復興巷１－１０號' '南投縣中寮鄉永福村永平路４４１―３號１樓' '南投縣仁愛鄉中正村平等巷７７號'
#  '南投縣仁愛鄉南豐村中正路１０４號' '南投縣仁愛鄉南豐村中正路１０８號' '南投縣仁愛鄉南豐村楓林路４３號' '南投縣仁愛鄉合作村平生路１９號'
#  '南投縣仁愛鄉大同村仁和路２１５號' '南投縣仁愛鄉大同村定遠新村２８號' '南投縣信義鄉明德村玉山路７３－５號']
# 統一編號 1	[19245758 26891323 45475516 6116979 6118857 78103657 18142065 99379552
#  81518363 94926948]
# 總機構統一編號 2	[nan nan nan nan nan nan nan nan 22941815.0 nan]
# 營業人名稱 3	['協農農機行' '草嶺園藝' '卓群園藝清潔社' '碧峰園' '山水園藝行' '花圤林木園藝種苗場' '觀之企業社'
#  '台大生物資源暨農學院附設山地實驗農場員工消費合作社' '青葉園藝有限公司清境營業所' '玉山原生種蘭花農場']
# 資本額 4	[3000 200000 240000 36000 3000 50000 5000 49000 0 300000]
# 設立日期 5	[890306 1000927 960613 761227 770523 811101 900702 930302 870723 921001]
# 使用統一發票 6	['N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N']
# 行業代號 7	[464317 813000 812100 485111 472935 485223 13012 472112 932100 11799]
# 名稱 8	['農業及園藝機械批發' '綠化服務' '建築物一般清潔服務' '切花、盆栽零售' '青草零售' '種子零售' '作物栽培服務' '水果零售'
#  '遊樂園及主題樂園' '其他花卉栽培']
# 行業代號1 9	[nan nan 812911.0 11999.0 nan 485111.0 485111.0 485111.0 472999.0 485111.0]
# 名稱1 10	[nan nan '病媒防治服務' '其他農作物栽培' nan '切花、盆栽零售' '切花、盆栽零售' '切花、盆栽零售'
#  '未分類其他食品、飲料及菸草製品零售' '切花、盆栽零售']
# 行業代號2 11	[nan nan nan nan nan nan 11799.0 474999.0 11799.0 nan]
# 名稱2 12	[nan nan nan nan nan nan '其他花卉栽培' '未分類其他家用器具及用品零售' '其他花卉栽培' nan]
# 行業代號3 13	[nan nan nan nan nan nan nan 472999.0 nan nan]
# 名稱3 14	[nan nan nan nan nan nan nan '未分類其他食品、飲料及菸草製品零售' nan nan]
# 0.3540523052215576
# data saved recode_fc_may_die.csv
